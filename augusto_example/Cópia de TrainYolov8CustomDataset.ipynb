# %%
ROOT_DIR = '/content/gdrive/MyDrive/YOLOv8_custom_training/YOLO-custom-dataset'

# %%
# !ls /content/gdrive
# Out:
# ls: cannot access '/content/gdrive': Transport endpoint is not connected

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.3/645.3 kB 11.0 MB/s eta 0:00:00
# ...

# %%
import os



from ultralytics import YOLO




# Load a model
model = YOLO("/content/gdrive/MyDrive/YOLOv8_custom_training/YOLO-MODELS/yolov8x.pt")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "colab_config.yaml"), epochs=1000, patience=300)  # train the model
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Caminho para o diretório de resultados do YOLO no Colab
yolo_results_path = '/content/runs/detect/train'

# Caminho para o diretório no Google Drive onde você deseja salvar os resultados
google_drive_path = '/content/gdrive/My Drive/YOLOv8_custom_training/YOLO-custom-results/train-3X(MILepochs)'

# Copiar os resultados do YOLO para o Google Drive
shutil.copytree(yolo_results_path, google_drive_path)
